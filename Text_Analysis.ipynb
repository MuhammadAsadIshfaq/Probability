# %%
# %pip install tabulate
from tabulate import tabulate
# Out:
# Requirement already satisfied: tabulate in c:\users\junaid\anaconda3\lib\site-packages (0.8.10)
# Requirement already satisfied: tabulate in c:\users\junaid\anaconda3\lib\site-packages (0.8.10)
# Note: you may need to restart the kernel to use updated packages.

# %%
import csv
from itertools import count
import operator
import math

EPSILON = 0.000001

def main():
    # Calculate all the ps and qs
    # Eg hamiltonWordProb['congress'] = 0.005
    # hamilton_word_prob['piech'] = 0.0
    # hamilton_word_prob['the'] = 0.001

    hamilton_word_prob = make_word_prob_map('kashmir.txt')
    madison_word_prob = make_word_prob_map('punjab.txt')

    

    # Get the word count of the unknown document
    # Eg unknown_doc_count['congress'] = 5
    unknown_doc_count, n_words = make_word_count_map('Kashmir bard.txt')

    #print("hamilton['congress']\t", hamilton_word_prob['congress'])
   # print("madison['congress']\t",  madison_word_prob['congress'])
   # print("doc_count['congress']\t", unknown_doc_count['congress'])
   # print("n_words", n_words)

    hamilton_term = calc_log_pr_doc_given_author(hamilton_word_prob, unknown_doc_count)
    madison_term = calc_log_pr_doc_given_author(madison_word_prob, unknown_doc_count)
    print("log P(D|H)\t", hamilton_term)
    print("log P(D|M)\t",madison_term)

    print('diff\t', hamilton_term - madison_term)

def calc_log_pr_doc_given_author(prob_map, counts):
    """
    How likely is the document, given the counts of words in the doc
    and the authors prob_map
    """
    data = []
    log_prob = math.log(1)
    for word_i, c_i in counts.items():
        p_i = get_word_prob(prob_map, word_i)
        log_prob += c_i * math.log(p_i)
        lst = [word_i, c_i, log_prob]
        data.append(lst)
        # print(word_i,"      ", c_i,"   ", log_prob,"   ")
    print(tabulate(data))
    return log_prob


def calcLogProbDoc(wordProbMap, countMap):
    logProb = math.log(1)
    for wordi in countMap:
        ci = countMap[wordi]
        pi = get_word_prob(wordProbMap, wordi)
        logProb += ci * math.log(pi)
    return logProb

# If a word is in a probability dictionary, return its probability
# otherwise, return epsilon
def get_word_prob(word_prob_map, word):
    if word in word_prob_map:
        return word_prob_map[word]
    return EPSILON

# From a file name, approximate the probability of a word
# being generated from the same distribution as the file.
# Assume that each word is produced independently, regardless
# of order.
def make_word_prob_map(fileName):
    wordMap, nWords = make_word_count_map(fileName)
    probabilityMap = {}
    for word in wordMap:
        count = wordMap[word]
        p = float(count) / nWords
        probabilityMap[word] = p
    return probabilityMap

# From a file name, count the number of times each word exists
# in that file. Return the result as a map (aka a dictionary)
def make_word_count_map(fileName):
    wordMap = {}
    nWords = 0
    data1 = []
    with open(fileName , encoding='utf-8') as f:
        for line in f:
            words = line.split(' ')
            for word in words:
                word = standardize(word)
                add_word_to_count_map(wordMap, word)
                nWords+= 1
                #lst1 = [word,wordMap[word]]
                #data1.append(lst1)
                #print(word, " ",wordMap[word] )
        #print(tabulate(data1))
    return wordMap, nWords

# Add a word to a count map. Makes sure not to crash if the
# word has not been seen before.
def add_word_to_count_map(wordMap, word):
    if not word in wordMap:
        wordMap[word] = 0
    wordMap[word] += 1
    
# Standardizes a word. For now, we are just going to make it
# lower case.
def standardize(word):
    standard = word.lower().strip()
    # remove punctuation
    standard = ''.join([i for i in standard if i.isalpha()])
    return standard

if __name__ == '__main__':
    main()
# Out:
# -----------------  --  ----------
# the                25    -55.7928
# history             1    -60.2758
# of                 17   -110.917
# kashmir            10   -151.693
# is                  3   -193.139
# a                   7   -216.83
# complex             1   -222.006
# and                21   -278.522
# contested           1   -292.338
# one                 1   -306.153
# involving           1   -319.969
# multiple            1   -333.784
# actors              1   -347.6
# perspectives        1   -361.415
# here                1   -375.231
# brief               1   -389.046
# summary             1   -402.862
# main                1   -416.677
# events              1   -430.493
# issues              1   -444.309
# that                1   -458.124
# have                4   -513.386
# shaped              1   -517.869
# regions             1   -531.685
# past                1   -545.5
# present             1   -559.316
#                    11   -608.629
# region              2   -616.784
# in                  8   -645.317
# northwestern        1   -659.133
# part                1   -664.309
# indian              2   -674.661
# subcontinent        1   -679.838
# surrounded          1   -693.653
# by                  4   -709.963
# himalayan           1   -723.779
# mountains           1   -737.594
# it                  4   -758.299
# has                 5   -784.18
# been                3   -825.626
# inhabited           1   -839.442
# various             1   -853.257
# peoples             1   -867.073
# cultures            1   -872.249
# including           1   -886.064
# hindu               3   -901.593
# buddhist            1   -906.769
# muslim              3   -948.215
# sikh                2   -975.846
# dogra               2   -986.199
# succession          1  -1000.01
# dynasties           1  -1005.19
# ruled               1  -1019.01
# until               1  -1024.18
# when                3  -1065.63
# came                1  -1079.44
# under               2  -1089.8
# rule                2  -1098.76
# period              1  -1103.94
# lasted              1  -1117.75
# nearly              1  -1131.57
# five                1  -1145.39
# centuries           1  -1159.2
# ending              1  -1173.02
# was                 2  -1200.65
# annexed             1  -1214.46
# to                  7  -1243.01
# kingdom             2  -1270.64
# punjab              1  -1284.45
# then                2  -1312.08
# jammu               1  -1317.26
# british             1  -1331.07
# india               8  -1366.94
# partitioned         1  -1380.75
# into                1  -1394.57
# independent         2  -1422.2
# states              1  -1436.02
# pakistan            5  -1461.9
# became              1  -1475.71
# disputed            1  -1489.53
# territory           1  -1503.34
# ruler               1  -1517.16
# maharaja            1  -1522.34
# hari                1  -1536.15
# singh               1  -1549.97
# wanted              1  -1563.78
# remain              1  -1577.6
# but                 2  -1605.23
# faced               1  -1619.04
# an                  3  -1634.57
# invasion            1  -1648.39
# pakistanibacked     1  -1662.2
# tribal              1  -1676.02
# militias            1  -1689.83
# he                  1  -1703.65
# signed              1  -1717.47
# instrument          1  -1731.28
# accession           1  -1745.1
# which               1  -1758.91
# gave                1  -1772.73
# control             4  -1790.66
# over                2  -1818.29
# kashmirs            1  -1822.77
# defense             1  -1836.59
# foreign             1  -1850.4
# affairs             1  -1864.22
# communications      1  -1878.04
# sent                1  -1891.85
# troops              1  -1905.67
# repel               1  -1919.48
# invaders            1  -1933.3
# war                 1  -1947.11
# ended               1  -1960.93
# with                2  -1969.89
# unbrokered          1  -1983.71
# ceasefire           3  -2025.16
# leaving             1  -2038.97
# portion             1  -2052.79
# pakistani           1  -2066.6
# line                3  -2082.13
# known               1  -2095.95
# as                  5  -2121.83
# de                  1  -2135.64
# facto               1  -2149.46
# border              1  -2163.27
# ever                1  -2177.09
# since               2  -2204.72
# although            1  -2218.54
# neither             1  -2232.35
# side                1  -2246.17
# recognizes          1  -2259.98
# international       1  -2273.8
# boundary            1  -2287.61
# site                1  -2301.43
# several             1  -2315.24
# wars                2  -2325.6
# conflicts           1  -2330.77
# between             1  -2335.95
# well                1  -2349.76
# internal            1  -2363.58
# unrest              1  -2368.76
# violence            2  -2396.39
# both                1  -2410.2
# countries           1  -2424.02
# claim               1  -2437.83
# entire              1  -2451.65
# their               2  -2462
# own                 1  -2475.82
# fought              1  -2489.63
# kashmiri            3  -2531.08
# people              2  -2541.43
# also                1  -2555.25
# expressed           1  -2569.06
# aspirations         1  -2574.24
# for                 1  -2579.42
# selfdetermination   1  -2593.23
# autonomy            1  -2607.05
# or                  1  -2620.86
# independence        1  -2634.68
# through             1  -2648.49
# peaceful            1  -2662.31
# armed               1  -2676.12
# movements           1  -2689.94
# some                1  -2703.75
# groups              1  -2717.57
# resorted            1  -2731.39
# militancy           1  -2745.2
# supported           1  -2759.02
# challenge           1  -2772.83
# accused             2  -2800.46
# sponsoring          1  -2814.28
# terrorism           1  -2828.09
# fomenting           1  -2841.91
# separatism          1  -2855.73
# while               1  -2869.54
# human               1  -2874.72
# rights              1  -2879.89
# violations          2  -2907.52
# repression          1  -2921.34
# situation           1  -2935.16
# remains             1  -2940.33
# tense               1  -2954.15
# volatile            1  -2967.96
# frequent            1  -2981.78
# clashes             1  -2995.59
# along               1  -3009.41
# periodic            1  -3023.22
# outbreaks           1  -3037.04
# protests            1  -3050.86
# valley              1  -3064.67
# -----------------  --  ----------
# -----------------  --  ----------
# the                25    -51.331
# history             1    -56.7515
# of                 17   -104.037
# kashmir            10   -242.192
# is                  3   -283.638
# a                   7   -306.201
# complex             1   -320.017
# and                21   -385.494
# contested           1   -399.309
# one                 1   -404.73
# involving           1   -418.545
# multiple            1   -432.361
# actors              1   -446.176
# perspectives        1   -459.992
# here                1   -473.808
# brief               1   -487.623
# summary             1   -501.439
# main                1   -515.254
# events              1   -529.07
# issues              1   -542.885
# that                1   -556.701
# have                4   -611.963
# shaped              1   -625.778
# regions             1   -631.199
# past                1   -645.014
# present             1   -658.83
#                    11   -703.206
# region              2   -711.85
# in                  8   -738.579
# northwestern        1   -752.394
# part                1   -757.122
# indian              2   -766.577
# subcontinent        1   -771.997
# surrounded          1   -785.813
# by                  4   -804.722
# himalayan           1   -818.538
# mountains           1   -832.353
# it                  4   -851.263
# has                 5   -878.365
# been                3   -894.627
# inhabited           1   -908.443
# various             1   -913.863
# peoples             1   -927.679
# cultures            1   -933.099
# including           1   -937.827
# hindu               3   -979.273
# buddhist            1   -993.089
# muslim              3  -1034.54
# sikh                2  -1043.99
# dogra               2  -1071.62
# succession          1  -1085.44
# dynasties           1  -1090.86
# ruled               1  -1104.67
# until               1  -1118.49
# when                3  -1159.93
# came                1  -1173.75
# under               2  -1201.38
# rule                2  -1229.01
# period              1  -1234.43
# lasted              1  -1248.25
# nearly              1  -1262.06
# five                1  -1275.88
# centuries           1  -1281.3
# ending              1  -1295.12
# was                 2  -1303.76
# annexed             1  -1309.18
# to                  7  -1342.27
# kingdom             2  -1369.9
# punjab              1  -1373.24
# then                2  -1400.87
# jammu               1  -1414.69
# british             1  -1419.42
# india               8  -1453.99
# partitioned         1  -1467.81
# into                1  -1481.62
# independent         2  -1509.25
# states              1  -1523.07
# pakistan            5  -1550.17
# became              1  -1554.9
# disputed            1  -1568.72
# territory           1  -1582.53
# ruler               1  -1596.35
# maharaja            1  -1610.16
# hari                1  -1623.98
# singh               1  -1637.79
# wanted              1  -1651.61
# remain              1  -1665.42
# but                 2  -1693.06
# faced               1  -1706.87
# an                  3  -1748.32
# invasion            1  -1762.13
# pakistanibacked     1  -1775.95
# tribal              1  -1789.76
# militias            1  -1803.58
# he                  1  -1817.39
# signed              1  -1831.21
# instrument          1  -1845.03
# accession           1  -1858.84
# which               1  -1872.66
# gave                1  -1886.47
# control             4  -1941.73
# over                2  -1952.58
# kashmirs            1  -1966.39
# defense             1  -1980.21
# foreign             1  -1994.02
# affairs             1  -2007.84
# communications      1  -2021.65
# sent                1  -2035.47
# troops              1  -2049.28
# repel               1  -2063.1
# invaders            1  -2076.92
# war                 1  -2090.73
# ended               1  -2104.55
# with                2  -2115.39
# unbrokered          1  -2129.2
# ceasefire           3  -2170.65
# leaving             1  -2184.46
# portion             1  -2198.28
# pakistani           1  -2203.7
# line                3  -2245.15
# known               1  -2258.96
# as                  5  -2286.07
# de                  1  -2299.88
# facto               1  -2313.7
# border              1  -2327.51
# ever                1  -2341.33
# since               2  -2368.96
# although            1  -2382.77
# neither             1  -2396.59
# side                1  -2410.41
# recognizes          1  -2424.22
# international       1  -2438.04
# boundary            1  -2451.85
# site                1  -2465.67
# several             1  -2471.09
# wars                2  -2481.93
# conflicts           1  -2495.74
# between             1  -2501.16
# well                1  -2514.98
# internal            1  -2528.8
# unrest              1  -2542.61
# violence            2  -2570.24
# both                1  -2584.06
# countries           1  -2597.87
# claim               1  -2611.69
# entire              1  -2625.5
# their               2  -2653.14
# own                 1  -2666.95
# fought              1  -2680.77
# kashmiri            3  -2722.21
# people              2  -2749.84
# also                1  -2763.66
# expressed           1  -2777.48
# aspirations         1  -2791.29
# for                 1  -2796.71
# selfdetermination   1  -2810.53
# autonomy            1  -2824.34
# or                  1  -2838.16
# independence        1  -2851.97
# through             1  -2865.79
# peaceful            1  -2879.6
# armed               1  -2893.42
# movements           1  -2907.24
# some                1  -2921.05
# groups              1  -2934.87
# resorted            1  -2948.68
# militancy           1  -2962.5
# supported           1  -2976.31
# challenge           1  -2990.13
# accused             2  -3017.76
# sponsoring          1  -3031.57
# terrorism           1  -3045.39
# fomenting           1  -3059.21
# separatism          1  -3073.02
# while               1  -3078.44
# human               1  -3092.26
# rights              1  -3106.07
# violations          2  -3133.7
# repression          1  -3147.52
# situation           1  -3161.33
# remains             1  -3175.15
# tense               1  -3188.97
# volatile            1  -3202.78
# frequent            1  -3216.6
# clashes             1  -3230.41
# along               1  -3244.23
# periodic            1  -3258.04
# outbreaks           1  -3271.86
# protests            1  -3285.67
# valley              1  -3291.1
# -----------------  --  ----------
# log P(D|H)	 -3064.6709236147976
# log P(D|M)	 -3291.0951281973926
# diff	 226.42420458259494

# %%
from tabulate import tabulate
import csv
from itertools import count
import operator
import math

EPSILON = 0.000001

def main():
    # Calculate all the ps and qs
    # Eg hamiltonWordProb['congress'] = 0.005
    # hamilton_word_prob['piech'] = 0.0
    # hamilton_word_prob['the'] = 0.001

    #hamilton_word_prob = make_word_prob_map('hamilton.txt')
    #madison_word_prob = make_word_prob_map('madison.txt')
    first_word_prob = make_word_prob_map('gilgit.txt')
    second_word_prob = make_word_prob_map('punjab.txt')
    third_word_prob = make_word_prob_map('kashmir.txt')
    fourth_word_prob = make_word_prob_map('kpk.txt')
    fifth_word_prob = make_word_prob_map('lahore.txt')

    

    # Get the word count of the unknown document
    # Eg unknown_doc_count['congress'] = 5
    unknown_doc_count, n_words = make_word_count_map('kashmir_bard.txt')

    #print("hamilton['congress']\t", hamilton_word_prob['congress'])
    #print("madison['congress']\t",  madison_word_prob['congress'])
    #print("doc_count['congress']\t", unknown_doc_count['congress'])
    print("n_words", n_words)

    first_term = calc_log_pr_doc_given_author(first_word_prob, unknown_doc_count)
    second_term = calc_log_pr_doc_given_author(second_word_prob, unknown_doc_count)
    third_term=  calc_log_pr_doc_given_author(third_word_prob, unknown_doc_count)
    fourth_term = calc_log_pr_doc_given_author(fourth_word_prob, unknown_doc_count)
    fifth_term = calc_log_pr_doc_given_author(fifth_word_prob, unknown_doc_count)
    
    print("log P(D|A)\t", first_term)
    print("log P(D|B)\t", second_term)
    print("log P(D|C)\t", third_term)
    print("log P(D|D)\t", fourth_term)
    print("log P(D|E)\t", fifth_term)
    
    
  
    def compare_var(var1, var2):
        result = var1 - var2
        if result > 0:
            return var1
        else:
            return var2

    unk = compare_var(first_term, second_term)
    unk = compare_var(unk, third_term)
    unk = compare_var(unk, fourth_term)
    unk = compare_var(unk, fifth_term)
    
    print('difference\t', unk)



def calc_log_pr_doc_given_author(prob_map, counts):
    """
    How likely is the document, given the counts of words in the doc
    and the authors prob_map
    """
    data = []
    log_prob = math.log(1)
    for word_i, c_i in counts.items():
        p_i = get_word_prob(prob_map, word_i)
        log_prob += c_i * math.log(p_i)
        lst = [word_i, c_i, log_prob]
        data.append(lst)
        # print(word_i,"      ", c_i,"   ", log_prob,"   ")
    print(tabulate(data))
    return log_prob


def calcLogProbDoc(wordProbMap, countMap):
    logProb = math.log(1)
    for wordi in countMap:
        ci = countMap[wordi]
        pi = get_word_prob(wordProbMap, wordi)
        logProb += ci * math.log(pi)
    return logProb

# If a word is in a probability dictionary, return its probability
# otherwise, return epsilon
def get_word_prob(word_prob_map, word):
    if word in word_prob_map:
        return word_prob_map[word]
    return EPSILON

# From a file name, approximate the probability of a word
# being generated from the same distribution as the file.
# Assume that each word is produced independently, regardless
# of order.
def make_word_prob_map(fileName):
    wordMap, nWords = make_word_count_map(fileName)
    probabilityMap = {}
    for word in wordMap:
        count = wordMap[word]
        p = float(count) / nWords
        probabilityMap[word] = p
    return probabilityMap

# From a file name, count the number of times each word exists
# in that file. Return the result as a map (aka a dictionary)
def make_word_count_map(fileName):
    wordMap = {}
    nWords = 0
    data1 = []
    with open(fileName , encoding='utf-8') as f:
        for line in f:
            words = line.split(' ')
            for word in words:
                word = standardize(word)
                add_word_to_count_map(wordMap, word)
                nWords+= 1
                #lst1 = [word,wordMap[word]]
                #data1.append(lst1)
                #print(word, " ",wordMap[word] )
        #print(tabulate(data1))
    return wordMap, nWords

# Add a word to a count map. Makes sure not to crash if the
# word has not been seen before.
def add_word_to_count_map(wordMap, word):
    if not word in wordMap:
        wordMap[word] = 0
    wordMap[word] += 1
    
# Standardizes a word. For now, we are just going to make it
# lower case.
def standardize(word):
    standard = word.lower().strip()
    # remove punctuation
    standard = ''.join([i for i in standard if i.isalpha()])
    return standard

if __name__ == '__main__':
    main()


# In[ ]:
# Out:
# n_words 292
# ----------------  --  ----------
# the               19    -41.7473
# history            2    -53.2524
# of                 6    -70.4256
# kashmir            5    -95.7227
# is                 1   -100.782
# a                 11   -142.655
# rich               1   -148.408
# and               16   -197.12
# complex            2   -224.751
# tapestry           1   -238.567
# woven              1   -252.382
# from               1   -258.135
# ancient            2   -269.64
# kingdoms           1   -283.456
# religious          1   -289.208
# influences         1   -294.961
# political          1   -308.776
# struggles          1   -322.592
# heres              1   -336.407
# brief              1   -350.223
# overview           1   -364.038
# in                 6   -385.37
# paragraph          1   -399.186
#                    8   -429.639
# early              1   -443.455
# nestled            1   -449.207
# amidst             1   -463.023
# majestic           1   -476.838
# himalayas          1   -482.591
# kashmirs           4   -537.853
# fertile            1   -551.668
# valleys            2   -579.3
# strategic          1   -584.359
# location           1   -598.174
# have               1   -603.234
# attracted          1   -617.049
# settlements        1   -630.865
# for                4   -653.875
# millennia          1   -667.691
# first              1   -681.506
# millennium         1   -695.322
# bce                1   -709.137
# hinduism           1   -722.953
# flourished         1   -736.768
# followed           2   -764.399
# by                 4   -787.41
# buddhism           1   -801.225
# under              4   -821.463
# emperor            1   -835.278
# ashoka             1   -849.094
# hindu              1   -862.909
# dynasties          1   -876.725
# like               1   -890.54
# karkotas           1   -904.356
# loharas            1   -918.171
# ruled              1   -931.987
# centuries          1   -945.802
# leaving            1   -959.618
# behind             1   -973.433
# legacy             1   -987.249
# magnificent        1  -1001.06
# temples            1  -1014.88
# vibrant            1  -1028.7
# shaivism           1  -1042.51
# philosophy         1  -1056.33
# muslim             2  -1083.96
# influence          1  -1089.71
# th                 2  -1099.83
# century            2  -1109.95
# islam              1  -1115.7
# arrived            1  -1129.52
# ushered            1  -1143.33
# shah               1  -1157.15
# mir                1  -1170.96
# subsequent         1  -1176.71
# rulers             1  -1190.53
# including          1  -1195.18
# mughals            1  -1209
# brought            1  -1222.82
# new                1  -1236.63
# artistic           1  -1250.45
# architectural      1  -1264.26
# styles             1  -1278.08
# blending           1  -1291.89
# them               1  -1305.71
# with               4  -1325.95
# existing           1  -1339.76
# cultural           2  -1348.05
# fabric             1  -1361.86
# this               2  -1389.49
# era                1  -1395.25
# saw                2  -1422.88
# construction       1  -1436.69
# iconic             1  -1450.51
# mosques            1  -1464.32
# gardens            1  -1478.14
# adding             1  -1491.96
# to                 4  -1509.42
# unique             1  -1523.24
# charm              1  -1537.05
# sikh               1  -1550.87
# dogra              1  -1564.68
# rule               1  -1578.5
# sikhs              1  -1592.31
# ranjit             1  -1606.13
# singh              2  -1633.76
# conquered          1  -1647.58
# dogras             2  -1675.21
# gulab              1  -1689.02
# period             1  -1694.77
# instability        1  -1708.59
# shift              1  -1722.41
# power              1  -1736.22
# dynamics           1  -1750.04
# ultimately         1  -1763.85
# establishing       1  -1777.67
# princely           1  -1783.42
# state              1  -1789.17
# british            1  -1794.23
# suzerainty         1  -1808.05
# postindependence   1  -1821.86
# partition          1  -1827.62
# india              2  -1839.12
# ignited            1  -1852.94
# conflict           1  -1866.75
# ongoing            1  -1880.57
# dispute            1  -1886.32
# over               1  -1900.14
# regions            1  -1913.95
# territorial        1  -1927.77
# claims             1  -1941.58
# remains            2  -1969.21
# divided            1  -1983.03
# between            1  -1988.78
# pakistan           1  -1993.44
# china              1  -1999.19
# aspirations        1  -2013
# autonomy           1  -2018.76
# yearning           1  -2032.57
# peace              1  -2046.39
# echoing            1  -2060.2
# through            1  -2074.02
# its                2  -2082.75
# image              1  -2096.57
# traditional        1  -2110.38
# kashmiri           2  -2138.01
# houseboat          1  -2151.83
# on                 1  -2165.64
# dal                1  -2179.46
# lake               1  -2193.27
# despite            1  -2199.03
# challenges         1  -2212.84
# heritage           1  -2218.6
# thrives            1  -2232.41
# cuisine            1  -2246.23
# music              1  -2260.04
# handicrafts        1  -2273.86
# continue           1  -2287.67
# mesmerize          1  -2301.49
# visitors           1  -2315.3
# breathtaking       1  -2329.12
# natural            1  -2334.87
# beauty             1  -2340.62
# snowcapped         1  -2354.44
# peaks              1  -2360.19
# pristine           1  -2374.01
# lakes              1  -2387.82
# lush               1  -2401.64
# meadows            1  -2415.45
# source             1  -2429.27
# solace             1  -2443.09
# inspiration        1  -2456.9
# delve              1  -2470.72
# deeper             1  -2484.53
# into               1  -2490.29
# fascinating        1  -2504.1
# you                1  -2517.92
# can                1  -2531.73
# explore            1  -2545.55
# many               1  -2559.36
# museums            1  -2573.18
# monuments          1  -2586.99
# ruins              1  -2600.81
# scattered          1  -2614.62
# across             1  -2628.44
# region             1  -2632.25
# each               1  -2646.06
# stone              1  -2659.88
# whispers           1  -2673.69
# story              1  -2687.51
# waiting            1  -2701.32
# be                 1  -2707.08
# discovered         1  -2720.89
# ----------------  --  ----------
# ----------------  --  ----------
# the               19    -40.853
# history            2    -51.8879
# of                 6    -69.1583
# kashmir            5   -138.236
# is                 1   -143.753
# a                 11   -189.196
# rich               1   -194.02
# and               16   -242.541
# complex            2   -270.172
# tapestry           1   -283.988
# woven              1   -297.803
# from               1   -303.321
# ancient            2   -314.355
# kingdoms           1   -328.171
# religious          1   -333.688
# influences         1   -347.504
# political          1   -361.319
# struggles          1   -375.135
# heres              1   -388.95
# brief              1   -402.766
# overview           1   -416.581
# in                 6   -437.21
# paragraph          1   -451.025
#                    8   -482.289
# early              1   -496.105
# nestled            1   -509.92
# amidst             1   -523.736
# majestic           1   -537.551
# himalayas          1   -551.367
# kashmirs           4   -606.629
# fertile            1   -620.444
# valleys            2   -648.075
# strategic          1   -661.891
# location           1   -675.706
# have               1   -689.522
# attracted          1   -703.337
# settlements        1   -717.153
# for                4   -772.415
# millennia          1   -786.23
# first              1   -800.046
# millennium         1   -813.861
# bce                1   -819.379
# hinduism           1   -833.194
# flourished         1   -838.712
# followed           2   -866.343
# by                 4   -888.413
# buddhism           1   -902.228
# under              4   -924.298
# emperor            1   -938.114
# ashoka             1   -951.929
# hindu              1   -965.745
# dynasties          1   -979.56
# like               1   -993.376
# karkotas           1  -1007.19
# loharas            1  -1021.01
# ruled              1  -1034.82
# centuries          1  -1040.34
# leaving            1  -1054.16
# behind             1  -1067.97
# legacy             1  -1081.79
# magnificent        1  -1095.6
# temples            1  -1109.42
# vibrant            1  -1114.93
# shaivism           1  -1128.75
# philosophy         1  -1142.57
# muslim             2  -1170.2
# influence          1  -1184.01
# th                 2  -1193.66
# century            2  -1202.5
# islam              1  -1216.31
# arrived            1  -1230.13
# ushered            1  -1243.94
# shah               1  -1257.76
# mir                1  -1271.58
# subsequent         1  -1285.39
# rulers             1  -1299.21
# including          1  -1304.72
# mughals            1  -1318.54
# brought            1  -1332.36
# new                1  -1346.17
# artistic           1  -1359.99
# architectural      1  -1373.8
# styles             1  -1387.62
# blending           1  -1401.43
# them               1  -1415.25
# with               4  -1437.32
# existing           1  -1451.13
# cultural           2  -1460.78
# fabric             1  -1474.6
# this               2  -1485.63
# era                1  -1499.45
# saw                2  -1510.48
# construction       1  -1524.3
# iconic             1  -1538.11
# mosques            1  -1551.93
# gardens            1  -1565.75
# adding             1  -1579.56
# to                 4  -1594.46
# unique             1  -1599.98
# charm              1  -1613.8
# sikh               1  -1618.22
# dogra              1  -1632.03
# rule               1  -1645.85
# sikhs              1  -1659.66
# ranjit             1  -1665.18
# singh              2  -1676.21
# conquered          1  -1690.03
# dogras             2  -1717.66
# gulab              1  -1731.48
# period             1  -1736.99
# instability        1  -1750.81
# shift              1  -1764.62
# power              1  -1778.44
# dynamics           1  -1792.26
# ultimately         1  -1806.07
# establishing       1  -1819.89
# princely           1  -1833.7
# state              1  -1838.53
# british            1  -1843.35
# suzerainty         1  -1857.17
# postindependence   1  -1870.98
# partition          1  -1876.5
# india              2  -1885.34
# ignited            1  -1899.15
# conflict           1  -1912.97
# ongoing            1  -1926.78
# dispute            1  -1940.6
# over               1  -1946.12
# regions            1  -1959.93
# territorial        1  -1973.75
# claims             1  -1987.56
# remains            2  -1998.6
# divided            1  -2012.41
# between            1  -2026.23
# pakistan           1  -2031.05
# china              1  -2044.87
# aspirations        1  -2058.68
# autonomy           1  -2072.5
# yearning           1  -2086.32
# peace              1  -2100.13
# echoing            1  -2113.95
# through            1  -2119.46
# its                2  -2128.3
# image              1  -2142.12
# traditional        1  -2155.93
# kashmiri           2  -2183.56
# houseboat          1  -2197.38
# on                 1  -2202.9
# dal                1  -2216.71
# lake               1  -2230.53
# despite            1  -2244.34
# challenges         1  -2258.16
# heritage           1  -2263.68
# thrives            1  -2277.49
# cuisine            1  -2291.31
# music              1  -2305.12
# handicrafts        1  -2318.94
# continue           1  -2332.75
# mesmerize          1  -2346.57
# visitors           1  -2360.38
# breathtaking       1  -2374.2
# natural            1  -2388.02
# beauty             1  -2401.83
# snowcapped         1  -2415.65
# peaks              1  -2429.46
# pristine           1  -2443.28
# lakes              1  -2457.09
# lush               1  -2470.91
# meadows            1  -2484.72
# source             1  -2498.54
# solace             1  -2512.36
# inspiration        1  -2526.17
# delve              1  -2539.99
# deeper             1  -2553.8
# into               1  -2567.62
# fascinating        1  -2581.43
# you                1  -2595.25
# can                1  -2609.06
# explore            1  -2622.88
# many               1  -2636.69
# museums            1  -2650.51
# monuments          1  -2664.33
# ruins              1  -2678.14
# scattered          1  -2691.96
# across             1  -2705.77
# region             1  -2710.6
# each               1  -2724.41
# stone              1  -2738.23
# whispers           1  -2752.04
# story              1  -2765.86
# waiting            1  -2779.67
# be                 1  -2793.49
# discovered         1  -2807.31
# ----------------  --  ----------
# ----------------  --  ----------
# the               19    -42.5735
# history            2    -51.6601
# of                 6    -69.2632
# kashmir            5    -87.7432
# is                 1    -93.3851
# a                 11   -134.041
# rich               1   -147.857
# and               16   -193.766
# complex            2   -205.049
# tapestry           1   -218.865
# woven              1   -232.681
# from               1   -246.496
# ancient            2   -257.78
# kingdoms           1   -271.595
# religious          1   -277.237
# influences         1   -282.879
# political          1   -287.828
# struggles          1   -301.643
# heres              1   -315.459
# brief              1   -329.274
# overview           1   -343.09
# in                 6   -363.758
# paragraph          1   -377.574
#                    8   -407.142
# early              1   -420.957
# nestled            1   -434.773
# amidst             1   -448.588
# majestic           1   -462.404
# himalayas          1   -476.219
# kashmirs           4   -498.787
# fertile            1   -512.602
# valleys            2   -540.233
# strategic          1   -554.049
# location           1   -567.864
# have               1   -572.813
# attracted          1   -586.629
# settlements        1   -600.444
# for                4   -617.467
# millennia          1   -631.282
# first              1   -645.098
# millennium         1   -658.913
# bce                1   -664.555
# hinduism           1   -670.197
# flourished         1   -684.012
# followed           2   -711.643
# by                 4   -729.817
# buddhism           1   -735.458
# under              4   -790.721
# emperor            1   -796.362
# ashoka             1   -802.004
# hindu              1   -815.82
# dynasties          1   -829.635
# like               1   -843.451
# karkotas           1   -857.266
# loharas            1   -871.082
# ruled              1   -884.897
# centuries          1   -898.713
# leaving            1   -912.528
# behind             1   -926.344
# legacy             1   -940.159
# magnificent        1   -953.975
# temples            1   -967.79
# vibrant            1   -981.606
# shaivism           1   -995.421
# philosophy         1  -1009.24
# muslim             2  -1020.52
# influence          1  -1026.16
# th                 2  -1035.25
# century            2  -1043.76
# islam              1  -1048.71
# arrived            1  -1062.52
# ushered            1  -1076.34
# shah               1  -1090.16
# mir                1  -1103.97
# subsequent         1  -1117.79
# rulers             1  -1123.43
# including          1  -1137.24
# mughals            1  -1151.06
# brought            1  -1164.88
# new                1  -1178.69
# artistic           1  -1192.51
# architectural      1  -1198.15
# styles             1  -1211.96
# blending           1  -1225.78
# them               1  -1239.59
# with               4  -1255.72
# existing           1  -1269.54
# cultural           2  -1279.44
# fabric             1  -1293.25
# this               2  -1320.88
# era                1  -1334.7
# saw                2  -1362.33
# construction       1  -1376.15
# iconic             1  -1389.96
# mosques            1  -1403.78
# gardens            1  -1417.59
# adding             1  -1431.41
# to                 4  -1446.81
# unique             1  -1460.62
# charm              1  -1474.44
# sikh               1  -1488.26
# dogra              1  -1502.07
# rule               1  -1515.89
# sikhs              1  -1529.7
# ranjit             1  -1543.52
# singh              2  -1571.15
# conquered          1  -1584.96
# dogras             2  -1612.59
# gulab              1  -1626.41
# period             1  -1640.23
# instability        1  -1654.04
# shift              1  -1667.86
# power              1  -1681.67
# dynamics           1  -1687.31
# ultimately         1  -1701.13
# establishing       1  -1714.95
# princely           1  -1720.59
# state              1  -1726.23
# british            1  -1731.18
# suzerainty         1  -1744.99
# postindependence   1  -1758.81
# partition          1  -1764.45
# india              2  -1772.96
# ignited            1  -1786.78
# conflict           1  -1792.42
# ongoing            1  -1806.24
# dispute            1  -1811.88
# over               1  -1825.69
# regions            1  -1839.51
# territorial        1  -1853.32
# claims             1  -1867.14
# remains            2  -1878.42
# divided            1  -1892.24
# between            1  -1897.88
# pakistan           1  -1902.42
# china              1  -1908.07
# aspirations        1  -1913.01
# autonomy           1  -1918.66
# yearning           1  -1932.47
# peace              1  -1938.11
# echoing            1  -1951.93
# through            1  -1965.74
# its                2  -1973.81
# image              1  -1987.63
# traditional        1  -2001.44
# kashmiri           2  -2029.07
# houseboat          1  -2042.89
# on                 1  -2047.84
# dal                1  -2061.65
# lake               1  -2075.47
# despite            1  -2089.28
# challenges         1  -2094.92
# heritage           1  -2108.74
# thrives            1  -2122.56
# cuisine            1  -2136.37
# music              1  -2150.19
# handicrafts        1  -2164
# continue           1  -2177.82
# mesmerize          1  -2191.63
# visitors           1  -2205.45
# breathtaking       1  -2219.26
# natural            1  -2233.08
# beauty             1  -2246.89
# snowcapped         1  -2260.71
# peaks              1  -2274.53
# pristine           1  -2288.34
# lakes              1  -2302.16
# lush               1  -2315.97
# meadows            1  -2329.79
# source             1  -2343.6
# solace             1  -2357.42
# inspiration        1  -2371.23
# delve              1  -2385.05
# deeper             1  -2398.87
# into               1  -2404.51
# fascinating        1  -2418.32
# you                1  -2432.14
# can                1  -2445.95
# explore            1  -2459.77
# many               1  -2473.58
# museums            1  -2487.4
# monuments          1  -2501.22
# ruins              1  -2515.03
# scattered          1  -2528.85
# across             1  -2542.66
# region             1  -2546.36
# each               1  -2560.17
# stone              1  -2573.99
# whispers           1  -2587.81
# story              1  -2601.62
# waiting            1  -2615.44
# be                 1  -2629.25
# discovered         1  -2643.07
# ----------------  --  ----------
# ----------------  --  ----------
# the               19    -42.9735
# history            2    -52.9131
# of                 6    -70.6426
# kashmir            5   -139.72
# is                 1   -144.284
# a                 11   -179.243
# rich               1   -193.059
# and               16   -242.627
# complex            2   -270.258
# tapestry           1   -284.073
# woven              1   -297.889
# from               1   -311.704
# ancient            2   -323.03
# kingdoms           1   -336.846
# religious          1   -350.661
# influences         1   -364.477
# political          1   -378.292
# struggles          1   -392.108
# heres              1   -405.923
# brief              1   -419.739
# overview           1   -433.554
# in                 6   -456.782
# paragraph          1   -470.597
#                    8   -500.333
# early              1   -514.149
# nestled            1   -527.964
# amidst             1   -541.78
# majestic           1   -555.595
# himalayas          1   -569.411
# kashmirs           4   -624.673
# fertile            1   -638.489
# valleys            2   -666.12
# strategic          1   -671.783
# location           1   -677.445
# have               1   -691.261
# attracted          1   -705.077
# settlements        1   -718.892
# for                4   -738.771
# millennia          1   -744.434
# first              1   -758.25
# millennium         1   -772.065
# bce                1   -785.881
# hinduism           1   -799.696
# flourished         1   -813.512
# followed           2   -841.143
# by                 4   -896.405
# buddhism           1   -902.068
# under              4   -924.72
# emperor            1   -938.535
# ashoka             1   -952.351
# hindu              1   -966.166
# dynasties          1   -971.136
# like               1   -984.952
# karkotas           1   -998.767
# loharas            1  -1012.58
# ruled              1  -1026.4
# centuries          1  -1040.21
# leaving            1  -1054.03
# behind             1  -1067.84
# legacy             1  -1081.66
# magnificent        1  -1095.48
# temples            1  -1109.29
# vibrant            1  -1123.11
# shaivism           1  -1136.92
# philosophy         1  -1150.74
# muslim             2  -1178.37
# influence          1  -1184.03
# th                 2  -1195.36
# century            2  -1206.68
# islam              1  -1220.5
# arrived            1  -1234.31
# ushered            1  -1248.13
# shah               1  -1261.95
# mir                1  -1275.76
# subsequent         1  -1289.58
# rulers             1  -1303.39
# including          1  -1309.05
# mughals            1  -1314.72
# brought            1  -1328.53
# new                1  -1342.35
# artistic           1  -1356.16
# architectural      1  -1369.98
# styles             1  -1383.8
# blending           1  -1397.61
# them               1  -1411.43
# with               4  -1429.68
# existing           1  -1443.5
# cultural           2  -1452.63
# fabric             1  -1458.29
# this               2  -1485.92
# era                1  -1499.74
# saw                2  -1511.06
# construction       1  -1524.88
# iconic             1  -1538.69
# mosques            1  -1552.51
# gardens            1  -1566.33
# adding             1  -1580.14
# to                 4  -1596.36
# unique             1  -1610.17
# charm              1  -1623.99
# sikh               1  -1637.8
# dogra              1  -1651.62
# rule               1  -1657.28
# sikhs              1  -1671.1
# ranjit             1  -1684.91
# singh              2  -1712.54
# conquered          1  -1726.36
# dogras             2  -1753.99
# gulab              1  -1767.8
# period             1  -1773.47
# instability        1  -1787.28
# shift              1  -1801.1
# power              1  -1814.91
# dynamics           1  -1828.73
# ultimately         1  -1842.54
# establishing       1  -1856.36
# princely           1  -1870.18
# state              1  -1883.99
# british            1  -1888.96
# suzerainty         1  -1902.78
# postindependence   1  -1916.59
# partition          1  -1930.41
# india              2  -1958.04
# ignited            1  -1971.85
# conflict           1  -1985.67
# ongoing            1  -1999.49
# dispute            1  -2013.3
# over               1  -2018.27
# regions            1  -2032.09
# territorial        1  -2045.9
# claims             1  -2059.72
# remains            2  -2087.35
# divided            1  -2101.16
# between            1  -2106.83
# pakistan           1  -2111.39
# china              1  -2125.21
# aspirations        1  -2139.02
# autonomy           1  -2152.84
# yearning           1  -2166.65
# peace              1  -2180.47
# echoing            1  -2194.28
# through            1  -2208.1
# its                2  -2217.23
# image              1  -2231.04
# traditional        1  -2244.86
# kashmiri           2  -2272.49
# houseboat          1  -2286.31
# on                 1  -2300.12
# dal                1  -2313.94
# lake               1  -2327.75
# despite            1  -2341.57
# challenges         1  -2347.23
# heritage           1  -2352.89
# thrives            1  -2366.71
# cuisine            1  -2380.52
# music              1  -2394.34
# handicrafts        1  -2408.16
# continue           1  -2421.97
# mesmerize          1  -2435.79
# visitors           1  -2449.6
# breathtaking       1  -2463.42
# natural            1  -2477.23
# beauty             1  -2491.05
# snowcapped         1  -2504.86
# peaks              1  -2518.68
# pristine           1  -2532.5
# lakes              1  -2546.31
# lush               1  -2560.13
# meadows            1  -2573.94
# source             1  -2587.76
# solace             1  -2601.57
# inspiration        1  -2615.39
# delve              1  -2629.2
# deeper             1  -2643.02
# into               1  -2656.83
# fascinating        1  -2670.65
# you                1  -2684.47
# can                1  -2698.28
# explore            1  -2712.1
# many               1  -2725.91
# museums            1  -2739.73
# monuments          1  -2753.54
# ruins              1  -2767.36
# scattered          1  -2781.17
# across             1  -2794.99
# region             1  -2799.04
# each               1  -2812.86
# stone              1  -2826.67
# whispers           1  -2840.49
# story              1  -2854.31
# waiting            1  -2868.12
# be                 1  -2873.78
# discovered         1  -2887.6
# ----------------  --  ----------
# ----------------  --  ----------
# the               19    -41.4729
# history            2    -51.3201
# of                 6    -68.0215
# kashmir            5   -137.099
# is                 1   -142.716
# a                 11   -180.331
# rich               1   -185.948
# and               16   -236.057
# complex            2   -263.688
# tapestry           1   -277.504
# woven              1   -291.319
# from               1   -305.135
# ancient            2   -332.766
# kingdoms           1   -346.582
# religious          1   -360.397
# influences         1   -374.213
# political          1   -388.028
# struggles          1   -401.844
# heres              1   -415.659
# brief              1   -429.475
# overview           1   -443.29
# in                 6   -468.673
# paragraph          1   -482.488
#                    8   -513.089
# early              1   -518.705
# nestled            1   -532.521
# amidst             1   -546.336
# majestic           1   -560.152
# himalayas          1   -573.967
# kashmirs           4   -629.229
# fertile            1   -643.045
# valleys            2   -670.676
# strategic          1   -684.491
# location           1   -698.307
# have               1   -712.122
# attracted          1   -725.938
# settlements        1   -739.753
# for                4   -759.448
# millennia          1   -773.263
# first              1   -787.079
# millennium         1   -792.696
# bce                1   -806.511
# hinduism           1   -820.327
# flourished         1   -825.944
# followed           2   -853.575
# by                 4   -873.269
# buddhism           1   -887.085
# under              4   -905.157
# emperor            1   -910.774
# ashoka             1   -924.59
# hindu              1   -930.206
# dynasties          1   -944.022
# like               1   -957.837
# karkotas           1   -971.653
# loharas            1   -985.468
# ruled              1   -999.284
# centuries          1  -1004.21
# leaving            1  -1018.02
# behind             1  -1031.84
# legacy             1  -1045.65
# magnificent        1  -1059.47
# temples            1  -1073.29
# vibrant            1  -1078.9
# shaivism           1  -1092.72
# philosophy         1  -1106.53
# muslim             2  -1134.16
# influence          1  -1147.98
# th                 2  -1157.83
# century            2  -1166.86
# islam              1  -1180.68
# arrived            1  -1194.49
# ushered            1  -1208.31
# shah               1  -1222.12
# mir                1  -1235.94
# subsequent         1  -1249.76
# rulers             1  -1263.57
# including          1  -1269.19
# mughals            1  -1283
# brought            1  -1296.82
# new                1  -1310.63
# artistic           1  -1324.45
# architectural      1  -1330.07
# styles             1  -1343.88
# blending           1  -1357.7
# them               1  -1371.51
# with               4  -1393.98
# existing           1  -1407.8
# cultural           2  -1416.26
# fabric             1  -1430.07
# this               2  -1457.7
# era                1  -1463.32
# saw                2  -1474.55
# construction       1  -1488.37
# iconic             1  -1502.19
# mosques            1  -1516
# gardens            1  -1529.82
# adding             1  -1543.63
# to                 4  -1559.66
# unique             1  -1573.48
# charm              1  -1587.29
# sikh               1  -1592.91
# dogra              1  -1606.72
# rule               1  -1611.24
# sikhs              1  -1616.86
# ranjit             1  -1622.48
# singh              2  -1633.71
# conquered          1  -1647.52
# dogras             2  -1675.16
# gulab              1  -1688.97
# period             1  -1694.59
# instability        1  -1708.4
# shift              1  -1722.22
# power              1  -1736.03
# dynamics           1  -1749.85
# ultimately         1  -1763.67
# establishing       1  -1777.48
# princely           1  -1791.3
# state              1  -1805.11
# british            1  -1810.04
# suzerainty         1  -1823.85
# postindependence   1  -1829.47
# partition          1  -1843.28
# india              2  -1870.91
# ignited            1  -1884.73
# conflict           1  -1898.55
# ongoing            1  -1912.36
# dispute            1  -1926.18
# over               1  -1931.1
# regions            1  -1944.92
# territorial        1  -1958.73
# claims             1  -1972.55
# remains            2  -1983.78
# divided            1  -1997.6
# between            1  -2011.41
# pakistan           1  -2016.34
# china              1  -2030.15
# aspirations        1  -2043.97
# autonomy           1  -2057.78
# yearning           1  -2071.6
# peace              1  -2085.41
# echoing            1  -2099.23
# through            1  -2104.84
# its                2  -2113.88
# image              1  -2127.7
# traditional        1  -2141.51
# kashmiri           2  -2169.14
# houseboat          1  -2182.96
# on                 1  -2196.77
# dal                1  -2210.59
# lake               1  -2224.41
# despite            1  -2238.22
# challenges         1  -2252.04
# heritage           1  -2257.65
# thrives            1  -2271.47
# cuisine            1  -2277.09
# music              1  -2290.9
# handicrafts        1  -2304.72
# continue           1  -2318.53
# mesmerize          1  -2332.35
# visitors           1  -2346.16
# breathtaking       1  -2359.98
# natural            1  -2373.79
# beauty             1  -2387.61
# snowcapped         1  -2401.43
# peaks              1  -2415.24
# pristine           1  -2429.06
# lakes              1  -2442.87
# lush               1  -2456.69
# meadows            1  -2470.5
# source             1  -2484.32
# solace             1  -2498.13
# inspiration        1  -2511.95
# delve              1  -2525.76
# deeper             1  -2539.58
# into               1  -2544.5
# fascinating        1  -2558.32
# you                1  -2572.13
# can                1  -2577.75
# explore            1  -2591.57
# many               1  -2605.38
# museums            1  -2619.2
# monuments          1  -2633.01
# ruins              1  -2646.83
# scattered          1  -2660.64
# across             1  -2674.46
# region             1  -2688.28
# each               1  -2702.09
# stone              1  -2715.91
# whispers           1  -2729.72
# story              1  -2743.54
# waiting            1  -2757.35
# be                 1  -2762.97
# discovered         1  -2776.79
# ----------------  --  ----------
# log P(D|A)	 -2720.8924332644597
# log P(D|B)	 -2807.305307388086
# log P(D|C)	 -2643.067107280456
# log P(D|D)	 -2887.5995844905383
# log P(D|E)	 -2776.7854838902535
# difference	 -2643.067107280456
